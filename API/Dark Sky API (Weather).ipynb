# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
# 8f65b8e645f19636fba7f90b531a7a4d

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
url = "https://api.darksky.net/forecast/8f65b8e645f19636fba7f90b531a7a4d/38.0293,-78.4767"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# JSON = JavaScript Object Notation
data = response.json()

# %%
data
# Out:
# {'currently': {'apparentTemperature': 72.15,
#   'cloudCover': 0.24,
#   'dewPoint': 56.11,
#   'humidity': 0.57,
#   'icon': 'clear-day',
#   'nearestStormBearing': 284,
#   'nearestStormDistance': 61,
#   'ozone': 360.95,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1011.23,
#   'summary': 'Clear',
#   'temperature': 72.15,
#   'time': 1496957393,
#   'visibility': 10,
#   'windBearing': 7,
#   'windSpeed': 6.08},
#  'daily': {'data': [{'apparentTemperatureMax': 72.41,
#     'apparentTemperatureMaxTime': 1496959200,
#     'apparentTemperatureMin': 55.34,
#     'apparentTemperatureMinTime': 1496916000,
#     'cloudCover': 0.49,
#     'dewPoint': 54.62,
#     'humidity': 0.76,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.47,
#     'ozone': 355.24,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1014.05,
#     'summary': 'Partly cloudy throughout the day.',
#     'sunriseTime': 1496915548,
#     'sunsetTime': 1496968584,
#     'temperatureMax': 72.41,
#     'temperatureMaxTime': 1496959200,
#     'temperatureMin': 55.34,
#     'temperatureMinTime': 1496916000,
#     'time': 1496894400,
#     'visibility': 9.73,
#     'windBearing': 16,
#     'windSpeed': 3.45},
#    {'apparentTemperatureMax': 81.14,
#     'apparentTemperatureMaxTime': 1497042000,
#     'apparentTemperatureMin': 54.33,
#     'apparentTemperatureMinTime': 1496998800,
#     'cloudCover': 0.16,
#     'dewPoint': 54.21,
#     'humidity': 0.66,
#     'icon': 'clear-day',
#     'moonPhase': 0.51,
#     'ozone': 350.82,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1011.77,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1497001939,
#     'sunsetTime': 1497055015,
#     'temperatureMax': 81.07,
#     'temperatureMaxTime': 1497042000,
#     'temperatureMin': 54.33,
#     'temperatureMinTime': 1496998800,
#     'time': 1496980800,
#     'visibility': 9.95,
#     'windBearing': 258,
#     'windSpeed': 3.55},
#    {'apparentTemperatureMax': 87.2,
#     'apparentTemperatureMaxTime': 1497124800,
#     'apparentTemperatureMin': 55.86,
#     'apparentTemperatureMinTime': 1497081600,
#     'cloudCover': 0.12,
#     'dewPoint': 57.82,
#     'humidity': 0.62,
#     'icon': 'partly-cloudy-day',
#     'moonPhase': 0.54,
#     'ozone': 342.03,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1016.66,
#     'summary': 'Partly cloudy in the morning.',
#     'sunriseTime': 1497088332,
#     'sunsetTime': 1497141445,
#     'temperatureMax': 86.68,
#     'temperatureMaxTime': 1497124800,
#     'temperatureMin': 55.86,
#     'temperatureMinTime': 1497081600,
#     'time': 1497067200,
#     'visibility': 10,
#     'windBearing': 217,
#     'windSpeed': 3.93},
#    {'apparentTemperatureMax': 95.24,
#     'apparentTemperatureMaxTime': 1497207600,
#     'apparentTemperatureMin': 64.21,
#     'apparentTemperatureMinTime': 1497168000,
#     'cloudCover': 0.02,
#     'dewPoint': 62.99,
#     'humidity': 0.62,
#     'icon': 'clear-day',
#     'moonPhase': 0.56,
#     'ozone': 314.11,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1019.79,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1497174726,
#     'sunsetTime': 1497227874,
#     'temperatureMax': 92.37,
#     'temperatureMaxTime': 1497207600,
#     'temperatureMin': 64.21,
#     'temperatureMinTime': 1497168000,
#     'time': 1497153600,
#     'visibility': 10,
#     'windBearing': 212,
#     'windSpeed': 4.21},
#    {'apparentTemperatureMax': 95.07,
#     'apparentTemperatureMaxTime': 1497304800,
#     'apparentTemperatureMin': 66.46,
#     'apparentTemperatureMinTime': 1497258000,
#     'cloudCover': 0.22,
#     'dewPoint': 63.81,
#     'humidity': 0.6,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.6,
#     'ozone': 308.55,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1018.72,
#     'summary': 'Partly cloudy starting in the afternoon.',
#     'sunriseTime': 1497261123,
#     'sunsetTime': 1497314300,
#     'temperatureMax': 92.76,
#     'temperatureMaxTime': 1497301200,
#     'temperatureMin': 66.46,
#     'temperatureMinTime': 1497258000,
#     'time': 1497240000,
#     'windBearing': 234,
#     'windSpeed': 3.64},
#    {'apparentTemperatureMax': 101.96,
#     'apparentTemperatureMaxTime': 1497387600,
#     'apparentTemperatureMin': 68.43,
#     'apparentTemperatureMinTime': 1497344400,
#     'cloudCover': 0.22,
#     'dewPoint': 67.59,
#     'humidity': 0.62,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.63,
#     'ozone': 309.93,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1016.89,
#     'summary': 'Partly cloudy starting in the afternoon.',
#     'sunriseTime': 1497347521,
#     'sunsetTime': 1497400726,
#     'temperatureMax': 95.72,
#     'temperatureMaxTime': 1497380400,
#     'temperatureMin': 68.43,
#     'temperatureMinTime': 1497344400,
#     'time': 1497326400,
#     'windBearing': 258,
#     'windSpeed': 2.75},
#    {'apparentTemperatureMax': 101.09,
#     'apparentTemperatureMaxTime': 1497466800,
#     'apparentTemperatureMin': 72.01,
#     'apparentTemperatureMinTime': 1497430800,
#     'cloudCover': 0.26,
#     'dewPoint': 68.8,
#     'humidity': 0.61,
#     'icon': 'partly-cloudy-night',
#     'moonPhase': 0.66,
#     'ozone': 304.01,
#     'precipIntensity': 0.0013,
#     'precipIntensityMax': 0.0032,
#     'precipIntensityMaxTime': 1497484800,
#     'precipProbability': 0.11,
#     'precipType': 'rain',
#     'pressure': 1015.58,
#     'summary': 'Mostly cloudy starting in the evening.',
#     'sunriseTime': 1497433921,
#     'sunsetTime': 1497487150,
#     'temperatureMax': 96.51,
#     'temperatureMaxTime': 1497466800,
#     'temperatureMin': 72.01,
#     'temperatureMinTime': 1497430800,
#     'time': 1497412800,
#     'windBearing': 241,
#     'windSpeed': 1.82},
#    {'apparentTemperatureMax': 102.37,
#     'apparentTemperatureMaxTime': 1497567600,
#     'apparentTemperatureMin': 71,
#     'apparentTemperatureMinTime': 1497517200,
#     'cloudCover': 0.57,
#     'dewPoint': 69.14,
#     'humidity': 0.65,
#     'icon': 'rain',
#     'moonPhase': 0.69,
#     'ozone': 298.34,
#     'precipIntensity': 0.0026,
#     'precipIntensityMax': 0.0049,
#     'precipIntensityMaxTime': 1497582000,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'pressure': 1012.57,
#     'summary': 'Drizzle overnight.',
#     'sunriseTime': 1497520323,
#     'sunsetTime': 1497573572,
#     'temperatureMax': 95.15,
#     'temperatureMaxTime': 1497560400,
#     'temperatureMin': 71,
#     'temperatureMinTime': 1497517200,
#     'time': 1497499200,
#     'windBearing': 234,
#     'windSpeed': 4.26}],
#   'icon': 'clear-day',
#   'summary': 'No precipitation throughout the week, with temperatures rising to 97°F on Wednesday.'},
#  'flags': {'isd-stations': ['722167-03718',
#    '722167-99999',
#    '722692-99999',
#    '723098-93798',
#    '723098-99999',
#    '723114-03715',
#    '723114-99999',
#    '724016-93736',
#    '724017-03707',
#    '724017-99999',
#    '724033-99999',
#    '724105-93760',
#    '724105-99999',
#    '999999-03759',
#    '999999-13732',
#    '999999-93708'],
#   'lamp-stations': ['KCHO', 'KLKU', 'KOMH', 'KSHD'],
#   'madis-stations': ['C6413',
#    'C8161',
#    'C8477',
#    'C9335',
#    'C9801',
#    'CHAV2',
#    'CROV2',
#    'D7692',
#    'D9115',
#    'E3764',
#    'E4342',
#    'E5086',
#    'E6602',
#    'E6603',
#    'KCHO',
#    'KGVE'],
#   'sources': ['lamp',
#    'gfs',
#    'cmc',
#    'nam',
#    'rap',
#    'rtma',
#    'sref',
#    'fnmoc',
#    'isd',
#    'madis',
#    'nearest-precip',
#    'nwspa',
#    'darksky'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 70.21,
#     'cloudCover': 0.21,
#     'dewPoint': 54.34,
#     'humidity': 0.57,
#     'icon': 'clear-day',
#     'ozone': 359.4,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.27,
#     'summary': 'Clear',
#     'temperature': 70.21,
#     'time': 1496955600,
#     'visibility': 10,
#     'windBearing': 8,
#     'windSpeed': 6.29},
#    {'apparentTemperature': 72.41,
#     'cloudCover': 0.27,
#     'dewPoint': 56.31,
#     'humidity': 0.57,
#     'icon': 'partly-cloudy-day',
#     'ozone': 362.51,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.18,
#     'summary': 'Partly Cloudy',
#     'temperature': 72.41,
#     'time': 1496959200,
#     'visibility': 10,
#     'windBearing': 5,
#     'windSpeed': 5.87},
#    {'apparentTemperature': 70.46,
#     'cloudCover': 0.24,
#     'dewPoint': 55.11,
#     'humidity': 0.58,
#     'icon': 'clear-day',
#     'ozone': 365.74,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.01,
#     'summary': 'Clear',
#     'temperature': 70.46,
#     'time': 1496962800,
#     'visibility': 10,
#     'windBearing': 15,
#     'windSpeed': 4.12},
#    {'apparentTemperature': 68.07,
#     'cloudCover': 0.18,
#     'dewPoint': 54.84,
#     'humidity': 0.63,
#     'icon': 'clear-day',
#     'ozone': 367.91,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.82,
#     'summary': 'Clear',
#     'temperature': 68.07,
#     'time': 1496966400,
#     'visibility': 10,
#     'windBearing': 29,
#     'windSpeed': 2.41},
#    {'apparentTemperature': 64.08,
#     'cloudCover': 0.44,
#     'dewPoint': 54.28,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-night',
#     'ozone': 368.17,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.74,
#     'summary': 'Partly Cloudy',
#     'temperature': 64.08,
#     'time': 1496970000,
#     'visibility': 10,
#     'windBearing': 48,
#     'windSpeed': 1.26},
#    {'apparentTemperature': 60.32,
#     'cloudCover': 0.48,
#     'dewPoint': 52.22,
#     'humidity': 0.75,
#     'icon': 'partly-cloudy-night',
#     'ozone': 367.36,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.84,
#     'summary': 'Partly Cloudy',
#     'temperature': 60.32,
#     'time': 1496973600,
#     'visibility': 10,
#     'windBearing': 148,
#     'windSpeed': 0.29},
#    {'apparentTemperature': 58.31,
#     'cloudCover': 0.64,
#     'dewPoint': 51.77,
#     'humidity': 0.79,
#     'icon': 'partly-cloudy-night',
#     'ozone': 366.78,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.89,
#     'summary': 'Mostly Cloudy',
#     'temperature': 58.31,
#     'time': 1496977200,
#     'visibility': 9.84,
#     'windBearing': 203,
#     'windSpeed': 1.19},
#    {'apparentTemperature': 57.43,
#     'cloudCover': 0.65,
#     'dewPoint': 51.78,
#     'humidity': 0.81,
#     'icon': 'partly-cloudy-night',
#     'ozone': 367.61,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.86,
#     'summary': 'Mostly Cloudy',
#     'temperature': 57.43,
#     'time': 1496980800,
#     'visibility': 9.95,
#     'windBearing': 228,
#     'windSpeed': 2.1},
#    {'apparentTemperature': 56.39,
#     'cloudCover': 0.54,
#     'dewPoint': 51.39,
#     'humidity': 0.83,
#     'icon': 'partly-cloudy-night',
#     'ozone': 368.66,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.72,
#     'summary': 'Partly Cloudy',
#     'temperature': 56.39,
#     'time': 1496984400,
#     'visibility': 9.75,
#     'windBearing': 237,
#     'windSpeed': 2.84},
#    {'apparentTemperature': 55.87,
#     'cloudCover': 0.53,
#     'dewPoint': 51.43,
#     'humidity': 0.85,
#     'icon': 'partly-cloudy-night',
#     'ozone': 367.73,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.59,
#     'summary': 'Partly Cloudy',
#     'temperature': 55.87,
#     'time': 1496988000,
#     'visibility': 9.82,
#     'windBearing': 242,
#     'windSpeed': 3.51},
#    {'apparentTemperature': 55.66,
#     'cloudCover': 0.37,
#     'dewPoint': 51.38,
#     'humidity': 0.85,
#     'icon': 'partly-cloudy-night',
#     'ozone': 362.82,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.48,
#     'summary': 'Partly Cloudy',
#     'temperature': 55.66,
#     'time': 1496991600,
#     'visibility': 9.89,
#     'windBearing': 246,
#     'windSpeed': 3.86},
#    {'apparentTemperature': 54.97,
#     'cloudCover': 0.13,
#     'dewPoint': 50.83,
#     'humidity': 0.86,
#     'icon': 'clear-night',
#     'ozone': 355.92,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.39,
#     'summary': 'Clear',
#     'temperature': 54.97,
#     'time': 1496995200,
#     'visibility': 9.83,
#     'windBearing': 250,
#     'windSpeed': 4.01},
#    {'apparentTemperature': 54.33,
#     'cloudCover': 0.2,
#     'dewPoint': 50.17,
#     'humidity': 0.86,
#     'icon': 'clear-night',
#     'ozone': 350.83,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.47,
#     'summary': 'Clear',
#     'temperature': 54.33,
#     'time': 1496998800,
#     'visibility': 9.84,
#     'windBearing': 254,
#     'windSpeed': 4.27},
#    {'apparentTemperature': 55.12,
#     'cloudCover': 0.08,
#     'dewPoint': 50.77,
#     'humidity': 0.85,
#     'icon': 'clear-day',
#     'ozone': 349.54,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1010.84,
#     'summary': 'Clear',
#     'temperature': 55.12,
#     'time': 1497002400,
#     'visibility': 9.88,
#     'windBearing': 258,
#     'windSpeed': 4.72},
#    {'apparentTemperature': 57.51,
#     'cloudCover': 0.03,
#     'dewPoint': 52.74,
#     'humidity': 0.84,
#     'icon': 'clear-day',
#     'ozone': 350.07,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.37,
#     'summary': 'Clear',
#     'temperature': 57.51,
#     'time': 1497006000,
#     'visibility': 9.87,
#     'windBearing': 262,
#     'windSpeed': 4.94},
#    {'apparentTemperature': 61.66,
#     'cloudCover': 0,
#     'dewPoint': 54.28,
#     'humidity': 0.77,
#     'icon': 'clear-day',
#     'ozone': 350.23,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.83,
#     'summary': 'Clear',
#     'temperature': 61.66,
#     'time': 1497009600,
#     'visibility': 10,
#     'windBearing': 270,
#     'windSpeed': 5.27},
#    {'apparentTemperature': 65.43,
#     'cloudCover': 0,
#     'dewPoint': 55.08,
#     'humidity': 0.69,
#     'icon': 'clear-day',
#     'ozone': 348.98,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.15,
#     'summary': 'Clear',
#     'temperature': 65.43,
#     'time': 1497013200,
#     'visibility': 10,
#     'windBearing': 279,
#     'windSpeed': 5.69},
#    {'apparentTemperature': 69.87,
#     'cloudCover': 0,
#     'dewPoint': 55.07,
#     'humidity': 0.59,
#     'icon': 'clear-day',
#     'ozone': 347.36,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.39,
#     'summary': 'Clear',
#     'temperature': 69.87,
#     'time': 1497016800,
#     'visibility': 10,
#     'windBearing': 289,
#     'windSpeed': 6.36},
#    {'apparentTemperature': 72.82,
#     'cloudCover': 0.08,
#     'dewPoint': 54.66,
#     'humidity': 0.53,
#     'icon': 'clear-day',
#     'ozone': 346.38,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.51,
#     'summary': 'Clear',
#     'temperature': 72.82,
#     'time': 1497020400,
#     'visibility': 10,
#     'windBearing': 295,
#     'windSpeed': 6.65},
#    {'apparentTemperature': 74.99,
#     'cloudCover': 0.09,
#     'dewPoint': 54.33,
#     'humidity': 0.49,
#     'icon': 'clear-day',
#     'ozone': 346.61,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.47,
#     'summary': 'Clear',
#     'temperature': 74.99,
#     'time': 1497024000,
#     'visibility': 10,
#     'windBearing': 296,
#     'windSpeed': 6.07},
#    {'apparentTemperature': 77.07,
#     'cloudCover': 0.11,
#     'dewPoint': 54.85,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'ozone': 347.47,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.32,
#     'summary': 'Clear',
#     'temperature': 77.07,
#     'time': 1497027600,
#     'visibility': 10,
#     'windBearing': 292,
#     'windSpeed': 5.19},
#    {'apparentTemperature': 78.7,
#     'cloudCover': 0.12,
#     'dewPoint': 55.18,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'ozone': 348.14,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.13,
#     'summary': 'Clear',
#     'temperature': 78.7,
#     'time': 1497031200,
#     'visibility': 10,
#     'windBearing': 284,
#     'windSpeed': 4.48},
#    {'apparentTemperature': 79.69,
#     'cloudCover': 0.14,
#     'dewPoint': 55.25,
#     'humidity': 0.43,
#     'icon': 'clear-day',
#     'ozone': 348.53,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.89,
#     'summary': 'Clear',
#     'temperature': 79.69,
#     'time': 1497034800,
#     'visibility': 10,
#     'windBearing': 272,
#     'windSpeed': 3.82},
#    {'apparentTemperature': 80.27,
#     'cloudCover': 0.07,
#     'dewPoint': 55.15,
#     'humidity': 0.42,
#     'icon': 'clear-day',
#     'ozone': 348.73,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.64,
#     'summary': 'Clear',
#     'temperature': 80.22,
#     'time': 1497038400,
#     'visibility': 10,
#     'windBearing': 256,
#     'windSpeed': 3.72},
#    {'apparentTemperature': 81.14,
#     'cloudCover': 0.11,
#     'dewPoint': 57.21,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'ozone': 348.22,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.52,
#     'summary': 'Clear',
#     'temperature': 81.07,
#     'time': 1497042000,
#     'visibility': 10,
#     'windBearing': 242,
#     'windSpeed': 3.66},
#    {'apparentTemperature': 78.38,
#     'cloudCover': 0.13,
#     'dewPoint': 57.4,
#     'humidity': 0.49,
#     'icon': 'clear-day',
#     'ozone': 346.15,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.57,
#     'summary': 'Clear',
#     'temperature': 78.38,
#     'time': 1497045600,
#     'visibility': 10,
#     'windBearing': 223,
#     'windSpeed': 3.35},
#    {'apparentTemperature': 75.75,
#     'cloudCover': 0.13,
#     'dewPoint': 58.45,
#     'humidity': 0.55,
#     'icon': 'clear-day',
#     'ozone': 343.37,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1011.76,
#     'summary': 'Clear',
#     'temperature': 75.75,
#     'time': 1497049200,
#     'visibility': 10,
#     'windBearing': 196,
#     'windSpeed': 3.1},
#    {'apparentTemperature': 73.07,
#     'cloudCover': 0.12,
#     'dewPoint': 58.74,
#     'humidity': 0.61,
#     'icon': 'clear-day',
#     'ozone': 341.85,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.12,
#     'summary': 'Clear',
#     'temperature': 73.07,
#     'time': 1497052800,
#     'visibility': 10,
#     'windBearing': 178,
#     'windSpeed': 3.12},
#    {'apparentTemperature': 69.76,
#     'cloudCover': 0.11,
#     'dewPoint': 57.44,
#     'humidity': 0.65,
#     'icon': 'clear-night',
#     'ozone': 342.77,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1012.75,
#     'summary': 'Clear',
#     'temperature': 69.76,
#     'time': 1497056400,
#     'visibility': 10,
#     'windBearing': 184,
#     'windSpeed': 2.97},
#    {'apparentTemperature': 65.37,
#     'cloudCover': 0.09,
#     'dewPoint': 54.85,
#     'humidity': 0.69,
#     'icon': 'clear-night',
#     'ozone': 344.95,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1013.54,
#     'summary': 'Clear',
#     'temperature': 65.37,
#     'time': 1497060000,
#     'visibility': 10,
#     'windBearing': 210,
#     'windSpeed': 3},
#    {'apparentTemperature': 61.99,
#     'cloudCover': 0.08,
#     'dewPoint': 52.69,
#     'humidity': 0.72,
#     'icon': 'clear-night',
#     'ozone': 346.83,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1014.23,
#     'summary': 'Clear',
#     'temperature': 61.99,
#     'time': 1497063600,
#     'visibility': 10,
#     'windBearing': 228,
#     'windSpeed': 3.33},
#    {'apparentTemperature': 60.19,
#     'cloudCover': 0.07,
#     'dewPoint': 51.91,
#     'humidity': 0.74,
#     'icon': 'clear-night',
#     'ozone': 347.84,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1014.69,
#     'summary': 'Clear',
#     'temperature': 60.19,
#     'time': 1497067200,
#     'visibility': 10,
#     'windBearing': 239,
#     'windSpeed': 3.37},
#    {'apparentTemperature': 59.29,
#     'cloudCover': 0.07,
#     'dewPoint': 51.75,
#     'humidity': 0.76,
#     'icon': 'clear-night',
#     'ozone': 348.56,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.03,
#     'summary': 'Clear',
#     'temperature': 59.29,
#     'time': 1497070800,
#     'visibility': 10,
#     'windBearing': 253,
#     'windSpeed': 3.18},
#    {'apparentTemperature': 58.29,
#     'cloudCover': 0.07,
#     'dewPoint': 51.31,
#     'humidity': 0.78,
#     'icon': 'clear-night',
#     'ozone': 349.12,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.32,
#     'summary': 'Clear',
#     'temperature': 58.29,
#     'time': 1497074400,
#     'visibility': 10,
#     'windBearing': 260,
#     'windSpeed': 3.12},
#    {'apparentTemperature': 56.95,
#     'cloudCover': 0.07,
#     'dewPoint': 50.59,
#     'humidity': 0.79,
#     'icon': 'clear-night',
#     'ozone': 349.37,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.52,
#     'summary': 'Clear',
#     'temperature': 56.95,
#     'time': 1497078000,
#     'visibility': 10,
#     'windBearing': 262,
#     'windSpeed': 3.25},
#    {'apparentTemperature': 55.86,
#     'cloudCover': 0.06,
#     'dewPoint': 50.02,
#     'humidity': 0.81,
#     'icon': 'clear-night',
#     'ozone': 349.47,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.66,
#     'summary': 'Clear',
#     'temperature': 55.86,
#     'time': 1497081600,
#     'visibility': 10,
#     'windBearing': 263,
#     'windSpeed': 3.41},
#    {'apparentTemperature': 56.01,
#     'cloudCover': 0.09,
#     'dewPoint': 50.21,
#     'humidity': 0.81,
#     'icon': 'clear-night',
#     'ozone': 350.03,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1015.87,
#     'summary': 'Clear',
#     'temperature': 56.01,
#     'time': 1497085200,
#     'visibility': 10,
#     'windBearing': 263,
#     'windSpeed': 3.5},
#    {'apparentTemperature': 58.4,
#     'cloudCover': 0.2,
#     'dewPoint': 52.01,
#     'humidity': 0.79,
#     'icon': 'clear-day',
#     'ozone': 351.9,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.21,
#     'summary': 'Clear',
#     'temperature': 58.4,
#     'time': 1497088800,
#     'visibility': 10,
#     'windBearing': 262,
#     'windSpeed': 3.41},
#    {'apparentTemperature': 62.88,
#     'cloudCover': 0.35,
#     'dewPoint': 55.35,
#     'humidity': 0.76,
#     'icon': 'partly-cloudy-day',
#     'ozone': 354.23,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.63,
#     'summary': 'Partly Cloudy',
#     'temperature': 62.88,
#     'time': 1497092400,
#     'visibility': 10,
#     'windBearing': 259,
#     'windSpeed': 3.23},
#    {'apparentTemperature': 67.3,
#     'cloudCover': 0.42,
#     'dewPoint': 58.04,
#     'humidity': 0.72,
#     'icon': 'partly-cloudy-day',
#     'ozone': 355.1,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.98,
#     'summary': 'Partly Cloudy',
#     'temperature': 67.3,
#     'time': 1497096000,
#     'visibility': 10,
#     'windBearing': 251,
#     'windSpeed': 3.26},
#    {'apparentTemperature': 71.51,
#     'cloudCover': 0.34,
#     'dewPoint': 59.38,
#     'humidity': 0.66,
#     'icon': 'partly-cloudy-day',
#     'ozone': 353.25,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.24,
#     'summary': 'Partly Cloudy',
#     'temperature': 71.51,
#     'time': 1497099600,
#     'visibility': 10,
#     'windBearing': 243,
#     'windSpeed': 3.66},
#    {'apparentTemperature': 76.09,
#     'cloudCover': 0.18,
#     'dewPoint': 59.98,
#     'humidity': 0.58,
#     'icon': 'clear-day',
#     'ozone': 349.93,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.44,
#     'summary': 'Clear',
#     'temperature': 76.09,
#     'time': 1497103200,
#     'visibility': 10,
#     'windBearing': 235,
#     'windSpeed': 4.24},
#    {'apparentTemperature': 80.9,
#     'cloudCover': 0.06,
#     'dewPoint': 60.2,
#     'humidity': 0.51,
#     'icon': 'clear-day',
#     'ozone': 347.05,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.53,
#     'summary': 'Clear',
#     'temperature': 80.01,
#     'time': 1497106800,
#     'visibility': 10,
#     'windBearing': 228,
#     'windSpeed': 4.73},
#    {'apparentTemperature': 83.15,
#     'cloudCover': 0.03,
#     'dewPoint': 60.52,
#     'humidity': 0.47,
#     'icon': 'clear-day',
#     'ozone': 345.52,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.51,
#     'summary': 'Clear',
#     'temperature': 82.77,
#     'time': 1497110400,
#     'visibility': 10,
#     'windBearing': 219,
#     'windSpeed': 5.08},
#    {'apparentTemperature': 84.97,
#     'cloudCover': 0.03,
#     'dewPoint': 60.96,
#     'humidity': 0.45,
#     'icon': 'clear-day',
#     'ozone': 344.43,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.38,
#     'summary': 'Clear',
#     'temperature': 84.73,
#     'time': 1497114000,
#     'visibility': 10,
#     'windBearing': 212,
#     'windSpeed': 5.5},
#    {'apparentTemperature': 86.29,
#     'cloudCover': 0.03,
#     'dewPoint': 61.37,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'ozone': 342.86,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1017.19,
#     'summary': 'Clear',
#     'temperature': 86.02,
#     'time': 1497117600,
#     'visibility': 10,
#     'windBearing': 206,
#     'windSpeed': 5.99},
#    {'apparentTemperature': 87.03,
#     'cloudCover': 0.04,
#     'dewPoint': 61.69,
#     'humidity': 0.43,
#     'icon': 'clear-day',
#     'ozone': 340.29,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.85,
#     'summary': 'Clear',
#     'temperature': 86.67,
#     'time': 1497121200,
#     'visibility': 10,
#     'windBearing': 202,
#     'windSpeed': 6.49},
#    {'apparentTemperature': 87.2,
#     'cloudCover': 0.05,
#     'dewPoint': 62.09,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'ozone': 337.25,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.44,
#     'summary': 'Clear',
#     'temperature': 86.68,
#     'time': 1497124800,
#     'visibility': 10,
#     'windBearing': 198,
#     'windSpeed': 6.87},
#    {'apparentTemperature': 86.93,
#     'cloudCover': 0.06,
#     'dewPoint': 62.72,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'ozone': 334.4,
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1016.21,
#     'summary': 'Clear',
#     'temperature': 86.14,
#     'time': 1497128400,
#     'visibility': 10,
#     'windBearing': 196,
#     'windSpeed': 6.85}],
#   'icon': 'partly-cloudy-night',
#   'summary': 'Partly cloudy starting later this evening.'},
#  'latitude': 38.0293,
#  'longitude': -78.4767,
#  'minutely': {'data': [{'precipIntensity': 0,
#     'precipProbability': 0,
#     'time': 1496957340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496957940},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958000},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958060},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958120},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958180},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958240},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958300},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958360},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958420},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958480},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958540},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958600},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958660},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958720},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958780},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958840},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958900},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496958960},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959020},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959080},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959140},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959200},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959260},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959320},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959380},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959440},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959500},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959560},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959620},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959680},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959740},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959800},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959860},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959920},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496959980},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960040},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960100},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960160},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960220},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960280},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960340},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960400},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960460},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960520},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960580},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960640},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960700},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960760},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960820},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960880},
#    {'precipIntensity': 0, 'precipProbability': 0, 'time': 1496960940}],
#   'icon': 'clear-day',
#   'summary': 'Clear for the hour.'},
#  'offset': -4,
#  'timezone': 'America/New_York'}

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'offset', 'currently', 'minutely', 'hourly', 'daily', 'flags'])

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data["currently"]
# Out:
# {'apparentTemperature': 72.15,
#  'cloudCover': 0.24,
#  'dewPoint': 56.11,
#  'humidity': 0.57,
#  'icon': 'clear-day',
#  'nearestStormBearing': 284,
#  'nearestStormDistance': 61,
#  'ozone': 360.95,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'pressure': 1011.23,
#  'summary': 'Clear',
#  'temperature': 72.15,
#  'time': 1496957393,
#  'visibility': 10,
#  'windBearing': 7,
#  'windSpeed': 6.08}

# %%
print("The current wind speed is", data["currently"]["windSpeed"], "miles per hour")
# Out:
# The current wind speed is 6.08 miles per hour

# %%
a = data["currently"]["apparentTemperature"] - data["currently"]["windSpeed"]

# %%
print("The difference is", a)
# Out:
# The difference is 66.07000000000001

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
type(data["daily"])
# Out:
# dict

# %%
data["daily"].keys()
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
type(data["daily"]["data"])
# Out:
# list

# %%
len(data['daily']['data'])
# Out:
# 8

# %%
data['daily']['data']
# Out:
# [{'apparentTemperatureMax': 72.41,
#   'apparentTemperatureMaxTime': 1496959200,
#   'apparentTemperatureMin': 55.34,
#   'apparentTemperatureMinTime': 1496916000,
#   'cloudCover': 0.49,
#   'dewPoint': 54.62,
#   'humidity': 0.76,
#   'icon': 'partly-cloudy-day',
#   'moonPhase': 0.47,
#   'ozone': 355.24,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1014.05,
#   'summary': 'Partly cloudy throughout the day.',
#   'sunriseTime': 1496915548,
#   'sunsetTime': 1496968584,
#   'temperatureMax': 72.41,
#   'temperatureMaxTime': 1496959200,
#   'temperatureMin': 55.34,
#   'temperatureMinTime': 1496916000,
#   'time': 1496894400,
#   'visibility': 9.73,
#   'windBearing': 16,
#   'windSpeed': 3.45},
#  {'apparentTemperatureMax': 81.14,
#   'apparentTemperatureMaxTime': 1497042000,
#   'apparentTemperatureMin': 54.33,
#   'apparentTemperatureMinTime': 1496998800,
#   'cloudCover': 0.16,
#   'dewPoint': 54.21,
#   'humidity': 0.66,
#   'icon': 'clear-day',
#   'moonPhase': 0.51,
#   'ozone': 350.82,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1011.77,
#   'summary': 'Clear throughout the day.',
#   'sunriseTime': 1497001939,
#   'sunsetTime': 1497055015,
#   'temperatureMax': 81.07,
#   'temperatureMaxTime': 1497042000,
#   'temperatureMin': 54.33,
#   'temperatureMinTime': 1496998800,
#   'time': 1496980800,
#   'visibility': 9.95,
#   'windBearing': 258,
#   'windSpeed': 3.55},
#  {'apparentTemperatureMax': 87.2,
#   'apparentTemperatureMaxTime': 1497124800,
#   'apparentTemperatureMin': 55.86,
#   'apparentTemperatureMinTime': 1497081600,
#   'cloudCover': 0.12,
#   'dewPoint': 57.82,
#   'humidity': 0.62,
#   'icon': 'partly-cloudy-day',
#   'moonPhase': 0.54,
#   'ozone': 342.03,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1016.66,
#   'summary': 'Partly cloudy in the morning.',
#   'sunriseTime': 1497088332,
#   'sunsetTime': 1497141445,
#   'temperatureMax': 86.68,
#   'temperatureMaxTime': 1497124800,
#   'temperatureMin': 55.86,
#   'temperatureMinTime': 1497081600,
#   'time': 1497067200,
#   'visibility': 10,
#   'windBearing': 217,
#   'windSpeed': 3.93},
#  {'apparentTemperatureMax': 95.24,
#   'apparentTemperatureMaxTime': 1497207600,
#   'apparentTemperatureMin': 64.21,
#   'apparentTemperatureMinTime': 1497168000,
#   'cloudCover': 0.02,
#   'dewPoint': 62.99,
#   'humidity': 0.62,
#   'icon': 'clear-day',
#   'moonPhase': 0.56,
#   'ozone': 314.11,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1019.79,
#   'summary': 'Clear throughout the day.',
#   'sunriseTime': 1497174726,
#   'sunsetTime': 1497227874,
#   'temperatureMax': 92.37,
#   'temperatureMaxTime': 1497207600,
#   'temperatureMin': 64.21,
#   'temperatureMinTime': 1497168000,
#   'time': 1497153600,
#   'visibility': 10,
#   'windBearing': 212,
#   'windSpeed': 4.21},
#  {'apparentTemperatureMax': 95.07,
#   'apparentTemperatureMaxTime': 1497304800,
#   'apparentTemperatureMin': 66.46,
#   'apparentTemperatureMinTime': 1497258000,
#   'cloudCover': 0.22,
#   'dewPoint': 63.81,
#   'humidity': 0.6,
#   'icon': 'partly-cloudy-night',
#   'moonPhase': 0.6,
#   'ozone': 308.55,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1018.72,
#   'summary': 'Partly cloudy starting in the afternoon.',
#   'sunriseTime': 1497261123,
#   'sunsetTime': 1497314300,
#   'temperatureMax': 92.76,
#   'temperatureMaxTime': 1497301200,
#   'temperatureMin': 66.46,
#   'temperatureMinTime': 1497258000,
#   'time': 1497240000,
#   'windBearing': 234,
#   'windSpeed': 3.64},
#  {'apparentTemperatureMax': 101.96,
#   'apparentTemperatureMaxTime': 1497387600,
#   'apparentTemperatureMin': 68.43,
#   'apparentTemperatureMinTime': 1497344400,
#   'cloudCover': 0.22,
#   'dewPoint': 67.59,
#   'humidity': 0.62,
#   'icon': 'partly-cloudy-night',
#   'moonPhase': 0.63,
#   'ozone': 309.93,
#   'precipIntensity': 0,
#   'precipIntensityMax': 0,
#   'precipProbability': 0,
#   'pressure': 1016.89,
#   'summary': 'Partly cloudy starting in the afternoon.',
#   'sunriseTime': 1497347521,
#   'sunsetTime': 1497400726,
#   'temperatureMax': 95.72,
#   'temperatureMaxTime': 1497380400,
#   'temperatureMin': 68.43,
#   'temperatureMinTime': 1497344400,
#   'time': 1497326400,
#   'windBearing': 258,
#   'windSpeed': 2.75},
#  {'apparentTemperatureMax': 101.09,
#   'apparentTemperatureMaxTime': 1497466800,
#   'apparentTemperatureMin': 72.01,
#   'apparentTemperatureMinTime': 1497430800,
#   'cloudCover': 0.26,
#   'dewPoint': 68.8,
#   'humidity': 0.61,
#   'icon': 'partly-cloudy-night',
#   'moonPhase': 0.66,
#   'ozone': 304.01,
#   'precipIntensity': 0.0013,
#   'precipIntensityMax': 0.0032,
#   'precipIntensityMaxTime': 1497484800,
#   'precipProbability': 0.11,
#   'precipType': 'rain',
#   'pressure': 1015.58,
#   'summary': 'Mostly cloudy starting in the evening.',
#   'sunriseTime': 1497433921,
#   'sunsetTime': 1497487150,
#   'temperatureMax': 96.51,
#   'temperatureMaxTime': 1497466800,
#   'temperatureMin': 72.01,
#   'temperatureMinTime': 1497430800,
#   'time': 1497412800,
#   'windBearing': 241,
#   'windSpeed': 1.82},
#  {'apparentTemperatureMax': 102.37,
#   'apparentTemperatureMaxTime': 1497567600,
#   'apparentTemperatureMin': 71,
#   'apparentTemperatureMinTime': 1497517200,
#   'cloudCover': 0.57,
#   'dewPoint': 69.14,
#   'humidity': 0.65,
#   'icon': 'rain',
#   'moonPhase': 0.69,
#   'ozone': 298.34,
#   'precipIntensity': 0.0026,
#   'precipIntensityMax': 0.0049,
#   'precipIntensityMaxTime': 1497582000,
#   'precipProbability': 0.2,
#   'precipType': 'rain',
#   'pressure': 1012.57,
#   'summary': 'Drizzle overnight.',
#   'sunriseTime': 1497520323,
#   'sunsetTime': 1497573572,
#   'temperatureMax': 95.15,
#   'temperatureMaxTime': 1497560400,
#   'temperatureMin': 71,
#   'temperatureMinTime': 1497517200,
#   'time': 1497499200,
#   'windBearing': 234,
#   'windSpeed': 4.26}]

# %%
today = data['daily']['data'][0]

# %%
# 0 corresponds to a new moon, 0.25 to a first quarter moon, 0.5 to a full moon, and 0.75 to a last quarter moon.

# %%
print("Our moon phase is", today['moonPhase'], "moon phase")
# Out:
# Our moon phase is 0.47 moon phase

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
today.keys()
# Out:
# dict_keys(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase', 'precipIntensity', 'precipIntensityMax', 'precipProbability', 'temperatureMin', 'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin', 'apparentTemperatureMinTime', 'apparentTemperatureMax', 'apparentTemperatureMaxTime', 'dewPoint', 'humidity', 'windSpeed', 'windBearing', 'visibility', 'cloudCover', 'pressure', 'ozone'])

# %%
b = today['temperatureMax'] - today['temperatureMin']
b
# Out:
# 17.069999999999993

# %%
print("The difference between the high and low temptures for today is", round(b))
# Out:
# The difference between the high and low temptures for today is 17

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
type(data['daily'])
# Out:
# dict

# %%
data['daily'].keys()
# Out:
# dict_keys(['summary', 'icon', 'data'])

# %%
daily_forcast = data['daily']['data']

# %%
len(daily_forcast)
# Out:
# 8

# %%
type(daily_forcast)
# Out:
# list

# %%
for day in daily_forcast:
    # print type([day])
    # print day.keys()
    # print(day['temperatureMax'])
    temp = day['temperatureMax']
    print("The highest temperature for today is", temp)
    if temp > 85:
        print("It is going to be hot")
    elif temp > 75:
        print("It is going to be warm out")
    else:
        print("It is going to be cold")
# Out:
# The highest temperature for today is 72.41
# It is going to be cold
# The highest temperature for today is 81.07
# It is going to be warm out
# The highest temperature for today is 86.68
# It is going to be hot
# The highest temperature for today is 92.37
# It is going to be hot
# The highest temperature for today is 92.76
# It is going to be hot
# The highest temperature for today is 95.72
# It is going to be hot
# The highest temperature for today is 96.51
# It is going to be hot
# The highest temperature for today is 95.15
# It is going to be hot

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
high_temp = daily_forcast[0]['temperatureMax']
highest_day = daily_forcast[0]['time']

for day in daily_forcast:
    print("Today's temp is", day['temperatureMax'])
    if day['temperatureMax'] > high_temp:
        high_temp = day['temperatureMax']
        highest_day = day['time']

print("The highest temperature is", high_temp, "on", highest_day)
# Out:
# Today's temp is 72.41
# Today's temp is 81.07
# Today's temp is 86.68
# Today's temp is 92.37
# Today's temp is 92.76
# Today's temp is 95.72
# Today's temp is 96.51
# Today's temp is 95.15
# The highest temperature is 96.51 on 1497412800
