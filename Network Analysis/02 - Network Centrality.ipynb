# %%
# %matplotlib inline

import pandas as pd
import networkx as nx

# Ignore matplotlib warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Using NetworkX to find centrality of points in your graph
#
# ## Read in our data

# %%
df = pd.read_csv("clubs.csv")
df.set_index('name', inplace=True)
df = df.pivot(columns='club', values='club').astype(bool).astype(int)
df.head(3)
# Out:
# club          Boston Committee  London Enemies  Long Room Club  Loyal Nine  \
# name
# Adams John                   0               0               1           0
# Adams Samuel                 1               1               1           0
# Allen Dr                     0               0               0           0
#
# club          North Caucus  St Andrews Lodge  Tea Party
# name
# Adams John               1                 0          0
# Adams Samuel             1                 0          0
# Allen Dr                 1                 0          0

# %% [markdown]
# ## Build the adjacency matrix
#
# Except I'm pretty sure technically it isn't an adjacency matrix, since an adjacency matrix is only `1` to mean "connected" and `0` to mean "not connected."

# %%
people_adj = df.dot(df.T)
people_adj.head()
# Out:
# name                Adams John  Adams Samuel  Allen Dr  Appleton Nathaniel  \
# name
# Adams John                   2             2         1                   1
# Adams Samuel                 2             4         1                   2
# Allen Dr                     1             1         1                   1
# Appleton Nathaniel           1             2         1                   2
# Ash Gilbert                  0             0         0                   0
#
# name                Ash Gilbert  Austin Benjamin  Austin Samuel  Avery John  \
# name
# Adams John                    0                0              0           0
# Adams Samuel                  0                1              1           1
# Allen Dr                      0                0              0           0
# Appleton Nathaniel            0                0              0           0
# Ash Gilbert                   1                0              0           0
#
# name                Baldwin Cyrus  Ballard John      ...       \
# name                                                 ...
# Adams John                      0             1      ...
# Adams Samuel                    1             1      ...
# Allen Dr                        0             1      ...
# Appleton Nathaniel              0             1      ...
# Ash Gilbert                     0             0      ...
#
# name                Whitwell William  Williams Jeremiah  Williams Jonathan  \
# name
# Adams John                         0                  0                  0
# Adams Samuel                       1                  0                  1
# Allen Dr                           0                  0                  0
# Appleton Nathaniel                 0                  0                  0
# Ash Gilbert                        0                  0                  0
#
# name                Williams Thomas  Willis Nathaniel  Wingfield William  \
# name
# Adams John                        0                 0                  0
# Adams Samuel                      0                 0                  0
# Allen Dr                          0                 0                  0
# Appleton Nathaniel                0                 0                  0
# Ash Gilbert                       0                 0                  1
#
# name                Winslow John  Winthrop John  Wyeth Joshua  Young Thomas
# name
# Adams John                     1              1             0             1
# Adams Samuel                   1              2             0             2
# Allen Dr                       0              1             0             1
# Appleton Nathaniel             0              1             0             2
# Ash Gilbert                    0              0             0             0
#
# [5 rows x 254 columns]

# %% [markdown]
# ## Build a graph...
#
# We'll draw it first, but **we're going to use it research, not for drawing!**

# %%
# %matplotlib inline
import networkx as nx

people_graph = nx.from_numpy_matrix(people_adj.values)

renamed = dict(zip(people_graph.nodes(), people_adj.columns))
print("Renaming nodes with", renamed)
nx.relabel_nodes(people_graph, renamed, copy=False)

nx.draw(people_graph, node_size=2, edge_color='lightgrey')
# Out:
# Renaming nodes with {0: 'Adams John', 1: 'Adams Samuel', 2: 'Allen Dr', 3: 'Appleton Nathaniel', 4: 'Ash Gilbert', 5: 'Austin Benjamin', 6: 'Austin Samuel', 7: 'Avery John', 8: 'Baldwin Cyrus', 9: 'Ballard John', 10: 'Barber Nathaniel', 11: 'Barnard Samuel', 12: 'Barrett Samuel', 13: 'Bass Henry', 14: 'Bell William', 15: 'Bewer James', 16: 'Blake Increase', 17: 'Boit John', 18: 'Bolter Thomas', 19: 'Boyer Peter', 20: 'Boynton Richard', 21: 'Brackett Jos', 22: 'Bradford John', 23: 'Bradlee David', 24: 'Bradlee Josiah', 25: 'Bradlee Nathaniel', 26: 'Bradlee Thomas', 27: 'Bray George', 28: 'Breck William', 29: 'Brimmer Herman', 30: 'Brimmer Martin', 31: 'Broomfield Henry', 32: 'Brown Enoch', 33: 'Brown Hugh', 34: 'Brown John', 35: 'Bruce Stephen', 36: 'Burbeck Edward', 37: 'Burbeck William', 38: 'Burt Benjamin', 39: 'Burton Benjamin', 40: 'Cailleteau Edward', 41: 'Callendar Elisha', 42: 'Campbell Nicholas', 43: 'Cazneau Capt', 44: 'Chadwell Mr', 45: 'Champney Caleb', 46: 'Chase Thomas', 47: 'Cheever Ezekiel', 48: 'Chipman Seth', 49: 'Chrysty Thomas', 50: 'Church Benjamin', 51: 'Clarke Benjamin', 52: 'Cleverly Stephen', 53: 'Cochran John', 54: 'Colesworthy Gilbert', 55: 'Collier Gershom', 56: 'Collins Ezra', 57: 'Collson Adam', 58: 'Condy JamesFoster', 59: 'Cooper Samuel', 60: 'Cooper William', 61: 'Crafts Thomas', 62: 'Crane John', 63: 'Davis Caleb', 64: 'Davis Edward', 65: 'Davis Robert', 66: 'Davis William', 67: 'Dawes Thomas', 68: 'Dennie William', 69: 'Deshon Moses', 70: 'Dexter Samuel', 71: 'Dolbear Edward', 72: 'Doyle Peter', 73: 'Eaton Joseph', 74: 'Eayres Joseph', 75: 'Eckley Unknown', 76: 'Edes Benjamin', 77: 'Emmes Samuel', 78: 'Etheridge William', 79: 'Fenno Samuel', 80: 'Ferrell Ambrose', 81: 'Field Joseph', 82: 'Flagg Josiah', 83: 'Fleet Thomas', 84: 'Foster Bos', 85: 'Foster Samuel', 86: 'Frothingham Nathaniel', 87: 'Gammell John', 88: 'Gill Moses', 89: 'Gore Samuel', 90: 'Gould William', 91: 'Graham James', 92: 'Grant Moses', 93: 'Gray Wait', 94: 'Greene Nathaniel', 95: 'Greenleaf Joseph', 96: 'Greenleaf William', 97: 'Greenough Newn', 98: 'Ham William', 99: 'Hammond Samuel', 100: 'Hancock Eben', 101: 'Hancock John', 102: 'Hendley William', 103: 'Hewes George', 104: 'Hickling William', 105: 'Hicks John', 106: 'Hill Alexander', 107: 'Hitchborn Nathaniel', 108: 'Hitchborn Thomas', 109: 'Hobbs Samuel', 110: 'Hoffins John', 111: 'Holmes Nathaniel', 112: 'Hooton John', 113: 'Hopkins Caleb', 114: 'Hoskins William', 115: 'Howard Samuel', 116: 'Howe Edward', 117: 'Hunnewell Jonathan', 118: 'Hunnewell Richard', 119: 'Hunstable Thomas', 120: 'Hunt Abraham', 121: 'Ingersoll Daniel', 122: 'Inglish Alexander', 123: 'Isaac Pierce', 124: 'Ivers James', 125: 'Jarvis Charles', 126: 'Jarvis Edward', 127: 'Jefferds Unknown', 128: 'Jenkins John', 129: 'Johnston Eben', 130: 'Johonnott Gabriel', 131: 'Kent Benjamin', 132: 'Kerr Walter', 133: 'Kimball Thomas', 134: 'Kinnison David', 135: 'Lambert John', 136: 'Lee Joseph', 137: 'Lewis Phillip', 138: 'Lincoln Amos', 139: 'Loring Matthew', 140: 'Lowell John', 141: 'MacKintosh Capt', 142: 'MacNeil Archibald', 143: 'Machin Thomas', 144: 'Mackay William', 145: 'Marett Phillip', 146: 'Marlton John', 147: 'Marshall Thomas', 148: 'Marson John', 149: 'Mason Jonathan', 150: 'Matchett John', 151: 'May John', 152: 'McAlpine William', 153: 'Melville Thomas', 154: 'Merrit John', 155: 'Milliken Thomas', 156: 'Molineux William', 157: 'Moody Samuel', 158: 'Moore Thomas', 159: 'Morse Anthony', 160: 'Morton Perez', 161: 'Mountford Joseph', 162: 'Newell Eliphelet', 163: 'Nicholls Unknown', 164: 'Noyces Nat', 165: 'Obear Israel', 166: 'Otis James', 167: 'Palfrey William', 168: 'Palmer Joseph', 169: 'Palms Richard', 170: 'Parker Jonathan', 171: 'Parkman Elias', 172: 'Partridge Sam', 173: 'Payson Joseph', 174: 'Pearce Isaac', 175: 'Pearce IsaacJun', 176: 'Peck Samuel', 177: 'Peck Thomas', 178: 'Peters John', 179: 'Phillips John', 180: 'Phillips Samuel', 181: 'Phillips William', 182: 'Pierce William', 183: 'Pier ...

# %% [markdown]
# ### Horrifying, let's try it again.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

# 1. Create the graph
people_graph = nx.from_numpy_matrix(people_adj.values)

# 1.5. Rename our nodes so it isn't 0,1,2,3,4,...
renamed = dict(zip(people_graph.nodes(), people_adj.columns))
nx.relabel_nodes(people_graph, renamed, copy=False)

# 2. Create a layout for our nodes 
layout = nx.spring_layout(people_graph, iterations=20, k=0.25)

# 3. Draw the parts we want
nx.draw_networkx_edges(people_graph, layout, edge_color='#e1e1e1')
nx.draw_networkx_nodes(people_graph, layout)
nx.draw_networkx_labels(people_graph, layout)

# 4. Turn off the axis because I know you don't want it
plt.axis('off')

# 5. Tell matplotlib to show it
plt.show()

# %% [markdown]
# Hmmm. Paul Revere and Warren Joseph seem to be in the middle, but are they actually important?

# %% [markdown]
# # Research topic: Centrality
#
# You can read more at [Wikipedia](https://en.wikipedia.org/wiki/Centrality), but centrality is **how connected you are to everyone else**. A common one is **closeness centrality**, and you can see more in the [networkx documentation](https://networkx.github.io/documentation/development/reference/algorithms.centrality.html).
#
# Let's say we make a graph (the same one we did before)...

# %%
# 1. Build the graph
people_graph = nx.from_numpy_matrix(people_adj.values)

# 2. Relabel the nodes with names instead of numbers
renamed = dict(zip(people_graph.nodes(), people_adj.columns))
nx.relabel_nodes(people_graph, renamed, copy=False)

# %% [markdown]
# You don't have to draw it! You can use it to then do calculate, like the aforementioned **closeness centrality**. You give networkx the graph you made, and it figures out how central every node is.

# %%
# Use networkx to calculate closeness in our graph
people_centrality = nx.closeness_centrality(people_graph)
people_centrality
# Out:
# {'Adams John': 0.5802752293577982,
#  'Adams Samuel': 0.6537467700258398,
#  'Allen Dr': 0.5647321428571429,
#  'Appleton Nathaniel': 0.5802752293577982,
#  'Ash Gilbert': 0.5572687224669604,
#  'Stevens Ebenezer': 0.6170731707317073,
#  'Stoddard Asa': 0.5647321428571429,
#  'Stoddard Jonathan': 0.5647321428571429,
#  'Story Elisha': 0.695054945054945,
#  'Swan James': 0.695054945054945,
#  'Sweetser John': 0.5163265306122449,
#  'Symmes Eben': 0.5647321428571429,
#  'Symmes John': 0.5647321428571429,
#  'Tabor Philip': 0.5572687224669604,
#  'Tileston Thomas': 0.5647321428571429,
#  'Trott George': 0.49510763209393344,
#  'Tyler Royall': 0.5121457489878543,
#  'Urann Thomas': 0.8031746031746032,
#  'Vernon Fortesque': 0.5685393258426966,
#  'Waldo Benjamin': 0.5685393258426966,
#  'Warren Joseph': 0.7485207100591716,
#  'Webb Joseph': 0.5572687224669604,
#  'Webster Thomas': 0.5572687224669604,
#  'Welles Henry': 0.5672645739910314,
#  'Wendell Oliver': 0.5816091954022988,
#  'Wheeler Josiah': 0.6170731707317073,
#  'White Samuel': 0.5647321428571429,
#  'Whitten John': 0.5572687224669604,
#  'Whitwell Samuel': 0.5685393258426966,
#  'Whitwell William': 0.5685393258426966,
#  'Williams Jeremiah': 0.6170731707317073,
#  'Williams Jonathan': 0.5685393258426966,
#  'Williams Thomas': 0.6170731707317073,
#  'Willis Nathaniel': 0.6170731707317073,
#  'Wingfield William': 0.5572687224669604,
#  'Winslow John': 0.5121457489878543,
#  'Winthrop John': 0.6293532338308457,
#  'Wyeth Joshua': 0.6170731707317073,
#  'Young Thomas': 0.71875}

# %%
eig_centrality = nx.eigenvector_centrality(people_graph)
eig_centrality
# Out:
# {'Adams John': 0.043013431281714316,
#  'Adams Samuel': 0.08627092883379778,
#  'Allen Dr': 0.036550282437213893,
#  'Appleton Nathaniel': 0.04782108610845371,
#  'Ash Gilbert': 0.008977228114293244,
#  'Austin Benjamin': 0.031986693880843645,
#  'Austin Samuel': 0.031986693880843645,
#  'Avery John': 0.03598684345980668,
#  'Baldwin Cyrus': 0.031986693880843645,
#  'Ballard John': 0.036550282437213893,
#  'Barber Nathaniel': 0.16184149972615802,
#  'Barnard Samuel': 0.08203371973686074,
#  'Barrett Samuel': 0.04096392199513692,
#  'Bass Henry': 0.15457084563388132,
#  'Bell William': 0.008977228114293244,
#  'Bewer James': 0.08203371973686074,
#  'Blake Increase': 0.008977228114293244,
#  'Boit John': 0.036550282437213893,
#  'Bolter Thomas': 0.08203371973686074,
#  'Boyer Peter': 0.031986693880843645,
#  'Boynton Richard': 0.04325749755208345,
#  'Brackett Jos': 0.031986693880843645,
#  'Bradford John': 0.04325749755208345,
#  'Bradlee David': 0.08203371973686074,
#  'Bradlee Josiah': 0.08203371973686074,
#  'Bradlee Nathaniel': 0.08203371973686074,
#  'Bradlee Thomas': 0.08203371973686074,
#  'Bray George': 0.008977228114293244,
#  'Breck William': 0.036550282437213893,
#  'Brimmer Herman': 0.031986693880843645,
#  'Brimmer Martin': 0.031986693880843645,
#  'Broomfield Henry': 0.031986693880843645,
#  'Brown Enoch': 0.031986693880843645,
#  'Brown Hugh': 0.008977228114293244,
#  'Brown John': 0.031986693880843645,
#  'Bruce Stephen': 0.08203371973686074,
#  'Peck Thomas': 0.036550282437213893,
#  'Peters John': 0.08203371973686074,
#  'Phillips John': 0.008977228114293244,
#  'Phillips Samuel': 0.006463148844500423,
#  'Phillips William': 0.031986693880843645,
#  'Pierce William': 0.08203371973686074,
#  'Pierpont Robert': 0.011270803671239806,
#  'Pitts John': 0.031986693880843645,
#  'Pitts Lendall': 0.08203371973686074,
#  'Pitts Samuel': 0.031986693880843645,
#  'Porter Thomas': 0.08203371973686074,
#  'Potter Edward': 0.008977228114293244,
#  'Powell William': 0.04325749755208345,
#  'Prentiss Henry': 0.08203371973686074,
#  'Prince Job': 0.031986693880843645,
#  'Prince John': 0.08203371973686074,
#  'Proctor Edward': 0.15057069605491827,
#  'Pulling John': 0.06853697631805757,
#  'Pulling Richard': 0.008977228114293244,
#  'Purkitt Henry': 0.08203371973686074,
#  'Quincy Josiah': 0.017733952515740226,
#  'Randall John': 0.08203371973686074,
#  'Revere Paul': 0.1660110730137118,
#  'Roby Joseph': 0.08203371973686074,
#  'Roylson Thomas': 0.031986693880843645,
#  'Ruddock Abiel': 0.06853697631805757,
#  'Russell John': 0.08203371973686074,
#  'Russell William': 0.08203371973686074,
#  'Sessions Robert': 0.08203371973686074,
#  'Seward James': 0.008977228114293244,
#  'Sharp Gibbens': 0.036550282437213893,
#  'Shed Joseph': 0.08203371973686074,
#  'Sigourney John': 0.036550282437213893,
#  'Simpson Benjamin': 0.08203371973686074,
#  'Slater Peter': 0.08203371973686074,
#  'Sloper Ambrose': 0.008977228114293244,
#  'Smith John': 0.004000149578963033,
#  'Spear Thomas': 0.08203371973686074,
#  'Sprague Samuel': 0.08203371973686074,
#  'Spurr John': 0.08203371973686074,
#  'Stanbridge Henry': 0.008977228114293244,
#  'Starr James': 0.08203371973686074,
#  'Stearns Phineas': 0.08203371973686074,
#  'Stevens Ebenezer': 0.08203371973686074,
#  'Stoddard Asa': 0.036550282437213893,
#  'Stoddard Jonathan': 0.036550282437213893,
#  'Story Elisha': 0.11858400217407472,
#  'Swan James': 0.11858400217407472,
#  'Sweetser John': 0.011270803671239806,
#  'Symmes Eben': 0.036550282437213893,
#  'Symmes John': 0.036550282437213893,
#  'Tabor Philip': 0.008977228114293244,
#  'Tileston Thomas': 0.036550282437213893,
#  'Trott George': 0.004000149578963033,
#  'Tyler Royall': 0.006463148844500423,
#  'Urann Thomas': 0.1275612302883679,
#  'Vernon Fortesque': 0.031986693880843645,
#  'Waldo Benjamin': 0.031986693880843645,
#  'Warren Joseph': 0.09524815694809091,
#  'Webb Joseph': 0.008977228114293244,
#  'Webster Thomas': 0.008977228114293244,
#  'Welles Henry': 0.012977377693256274,
#  'Wendell Oliver': 0.04325749755208345,
#  'Wheeler Josiah': 0.08203371973686074,
#  'White Samuel': 0.036550282437213893,
#  'Whitten John': 0.008977228114293244,
#  'Whitwell Samuel': 0.031986693880843645,
#  'Whitwell William': 0.031986693880843645,
#  'Williams Jeremiah': 0.08203371973686074,
#  'Williams Jonathan': 0.031986693880843645,
#  'Williams Thomas': 0.08203371973686074,
#  'Willis Nathaniel': 0.08203371973686074,
#  'Wingfield William': 0.008977228114293244,
#  'Winslow John': 0.006463148844500423,
#  'Winthrop John': 0.06853697631805757,
#  'Wyeth Joshua': 0.08203371973686074,
#  'Young Thomas': 0.12985480584531456}

# %% [markdown]
# You can use this weird magic code to print out the top 10 most central points.

# %%
for name in sorted(people_centrality, key=people_centrality.get, reverse=True)[:10]:
    print(name, people_centrality[name])
    
# higher the number, more central you are
# Out:
# Revere Paul 0.9693486590038314
# Barber Nathaniel 0.8083067092651757
# Bass Henry 0.8083067092651757
# Chase Thomas 0.8083067092651757
# Urann Thomas 0.8031746031746032
# Condy JamesFoster 0.7931034482758621
# Grant Moses 0.7931034482758621
# Proctor Edward 0.7931034482758621
# Warren Joseph 0.7485207100591716
# Molineux William 0.71875

# %%
for name in sorted(eig_centrality, key=people_centrality.get, reverse=True)[:10]:
    print(name, people_centrality[name])
    
# higher the number, more central you are
# Out:
# Revere Paul 0.9693486590038314
# Barber Nathaniel 0.8083067092651757
# Bass Henry 0.8083067092651757
# Chase Thomas 0.8083067092651757
# Urann Thomas 0.8031746031746032
# Condy JamesFoster 0.7931034482758621
# Grant Moses 0.7931034482758621
# Proctor Edward 0.7931034482758621
# Warren Joseph 0.7485207100591716
# Molineux William 0.71875

# %% [markdown]
# # Other network-y stuff
#
# Networkx has a lot of other [algorithms you can use](https://networkx.github.io/documentation/development/reference/algorithms.html) for tasks like finding cliques or running [PageRank](https://networkx.github.io/documentation/development/reference/algorithms.link_analysis.html#module-networkx.algorithms.link_analysis.pagerank_alg) on it!

# %% [markdown]
# ### Finding cliques
#
# This dataset sucks for cliques, but if you have something more interesting...!

# %%
list(nx.find_cliques(people_graph))
# Out:
# [['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Hancock John',
#   'Adams John',
#   'Cooper Samuel',
#   'Barber Nathaniel'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Hancock John',
#   'Adams John',
#   'Cooper Samuel',
#   'Dawes Thomas',
#   'Phillips Samuel',
#   'Fleet Thomas',
#   'Dexter Samuel',
#   'Winslow John',
#   'Cooper William',
#   'Lambert John',
#   'Tyler Royall'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Hancock John',
#   'Adams John',
#   'Greenleaf Joseph',
#   'Barber Nathaniel'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Hancock John',
#   'Wendell Oliver',
#   'Barber Nathaniel',
#   'Powell William',
#   'Bradford John',
#   'Davis Caleb',
#   'Greenleaf Joseph',
#   'Boynton Richard',
#   'Greenleaf William'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Appleton Nathaniel',
#   'Barber Nathaniel',
#   'Molineux William',
#   'Young Thomas',
#   'Dennie William',
#   'Greenleaf Joseph',
#   'Wendell Oliver',
#   'Powell William',
#   'Davis Caleb',
#   'Bradford John',
#   'Boynton Richard',
#   'Greenleaf William'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Appleton Nathaniel',
#   'Barber Nathaniel',
#   'Molineux William',
#   'Young Thomas',
#   'Dennie William',
#   'Greenleaf Joseph',
#   'Adams John'],
#  ['Revere Paul',
#   'Quincy Josiah',
#   'Warren Joseph',
#   'Otis James',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Young Thomas',
#   'Barber Nathaniel',
#   'Cooper Samuel',
#   'Adams John',
#   'Molineux William'],
#  ['Revere Paul',
#   'Roylson Thomas',
#   'Warren Joseph',
#   'Greenough Newn',
#   'Cheever Ezekiel',
#   'Davis Edward',
#   'Broomfield Henry',
#   'Mason Jonathan',
#   'Noyces Nat',
#   'Greenleaf Joseph',
#   'Jarvis Charles',
#   'Barber Nathaniel',
#   'Gill Moses',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Whitwell William',
#   'Marson John',
#   'Hopkins Caleb',
#   'Davis William',
#   'Pulling John',
#   'Bradford John',
#   'Barrett Samuel',
#   'Austin Benjamin',
#   'Boynton Richard',
#   'Phillips William',
#   'Whitwell Samuel',
#   'Foster Bos',
#   'Chase Thomas',
#   'Austin Samuel',
#   'Partridge Sam',
#   'Hancock John',
#   'Vernon Fortesque',
#   'Brimmer Martin',
#   'Powell William',
#   'Boyer Peter',
#   'Marshall Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Eayres Joseph',
#   'Isaac Pierce',
#   'Pitts Samuel',
#   'Winthrop John',
#   'Brimmer Herman',
#   'Johnston Eben',
#   'Prince Job',
#   'Brown Enoch',
#   'Wendell Oliver',
#   'Church Benjamin',
#   'Avery John',
#   'Brown John',
#   'Greenleaf William',
#   'Grant Moses',
#   'Waldo Benjamin',
#   'Ivers James',
#   'Hancock Eben',
#   'Baldwin Cyrus',
#   'Parkman Elias',
#   'Davis Caleb',
#   'Williams Jonathan',
#   'Pitts John',
#   'Condy JamesFoster',
#   'Brackett Jos'],
#  ['Revere Paul',
#   'Bradford John',
#   'Warren Joseph',
#   'Cheever Ezekiel',
#   'Greenleaf Joseph',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Pulling John',
#   'Boynton Richard',
#   'Chase Thomas',
#   'Powell William',
#   'Proctor Edward',
#   'Bass Henry',
#   'Winthrop John',
#   'Parkman Elias',
#   'Condy JamesFoster',
#   'Church Benjamin',
#   'Wendell Oliver',
#   'Grant Moses',
#   'Greenleaf William',
#   'Davis Caleb',
#   'Dennie William',
#   'Young Thomas',
#   'Molineux William',
#   'Appleton Nathaniel'],
#  ['Revere Paul',
#   'Bradford John',
#   'Warren Joseph',
#   'Cheever Ezekiel',
#   'Greenleaf Joseph',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Pulling John',
#   'Boynton Richard',
#   'Chase Thomas',
#   'Powell William',
#   'Proctor Edward',
#   'Bass Henry',
#   'Winthrop John',
#   'Parkman Elias',
#   'Condy JamesFoster',
#   'Church Benjamin',
#   'Wendell Oliver',
#   'Grant Moses',
#   'Greenleaf William',
#   'Davis Caleb',
#   'Eayres Joseph',
#   'Young Thomas',
#   'Molineux William'],
#  ['Revere Paul',
#   'Hancock John',
#   'Warren Joseph',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Barber Nathaniel',
#   'Chase Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Grant Moses',
#   'Adams John',
#   'Ruddock Abiel',
#   'Pulling John',
#   'Parkman Elias',
#   'Cheever Ezekiel',
#   'Greenleaf Joseph',
#   'Winthrop John'],
#  ['Revere Paul',
#   'Hancock John',
#   'Warren Joseph',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Barber Nathaniel',
#   'Chase Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Grant Moses',
#   'Adams John',
#   'Cooper Samuel'],
#  ['Revere Paul',
#   'Hancock John',
#   'Warren Joseph',
#   'Adams Samuel',
#   'Church Benjamin',
#   'Barber Nathaniel',
#   'Chase Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Grant Moses',
#   'Cooper Samuel',
#   'Eayres Joseph'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Champney Caleb',
#   'Warren Joseph',
#   'Collson Adam',
#   'Story Elisha',
#   'Morton Perez',
#   'Burt Benjamin',
#   'Pearce IsaacJun',
#   'Cazneau Capt',
#   'Cheever Ezekiel',
#   'Chadwell Mr',
#   'Boit John',
#   'White Samuel',
#   'Greenleaf Joseph',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Holmes Nathaniel',
#   'Adams Samuel',
#   'Stoddard Jonathan',
#   'Peck Thomas',
#   'Pearce Isaac',
#   'Pulling John',
#   'Hitchborn Thomas',
#   'Dennie William',
#   'Swan James',
#   'Edes Benjamin',
#   'Chase Thomas',
#   'Merrit John',
#   'Emmes Samuel',
#   'Stoddard Asa',
#   'Johonnott Gabriel',
#   'Matchett John',
#   'Lowell John',
#   'Tileston Thomas',
#   'Kimball Thomas',
#   'Young Thomas',
#   'Molineux William',
#   'Proctor Edward',
#   'Palms Richard',
#   'Symmes John',
#   'Symmes Eben',
#   'Adams John',
#   'Hickling William',
#   'Appleton Nathaniel',
#   'Breck William',
#   'Condy JamesFoster',
#   'Church Benjamin',
#   'Chrysty Thomas',
#   'Grant Moses',
#   'Bass Henry',
#   'Ballard John',
#   'Winthrop John',
#   'Sigourney John',
#   'Parkman Elias',
#   'Allen Dr',
#   'Sharp Gibbens',
#   'Hoskins William',
#   'Kent Benjamin'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Cheever Ezekiel',
#   'Warren Joseph',
#   'Greenleaf Joseph',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Pulling John',
#   'Chase Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Winthrop John',
#   'Parkman Elias',
#   'Condy JamesFoster',
#   'Church Benjamin',
#   'Grant Moses',
#   'Eayres Joseph',
#   'Story Elisha',
#   'Collson Adam',
#   'Swan James',
#   'Molineux William',
#   'Young Thomas'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Cheever Ezekiel',
#   'Warren Joseph',
#   'Greenleaf Joseph',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Pulling John',
#   'Chase Thomas',
#   'Proctor Edward',
#   'Bass Henry',
#   'Winthrop John',
#   'Parkman Elias',
#   'Condy JamesFoster',
#   'Church Benjamin',
#   'Grant Moses',
#   'Eayres Joseph',
#   'Barrett Samuel'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Adams Samuel',
#   'Warren Joseph',
#   'Cooper Samuel',
#   'Story Elisha',
#   'Collson Adam',
#   'Barber Nathaniel',
#   'Church Benjamin',
#   'Young Thomas',
#   'Molineux William',
#   'Proctor Edward',
#   'Grant Moses',
#   'Bass Henry',
#   'Swan James',
#   'Condy JamesFoster',
#   'Chase Thomas',
#   'Adams John'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Adams Samuel',
#   'Warren Joseph',
#   'Cooper Samuel',
#   'Story Elisha',
#   'Collson Adam',
#   'Barber Nathaniel',
#   'Church Benjamin',
#   'Young Thomas',
#   'Molineux William',
#   'Proctor Edward',
#   'Grant Moses',
#   'Bass Henry',
#   'Swan James',
#   'Condy JamesFoster',
#   'Chase Thomas',
#   'Eayres Joseph'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Edes Benjamin',
#   'Warren Joseph',
#   'Chase Thomas',
#   'Bass Henry',
#   'Crafts Thomas',
#   'Welles Henry'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Peck Samuel',
#   'Deshon Moses',
#   'Warren Joseph',
#   'Welles Henry',
#   'Jefferds Unknown',
#   'Callendar Elisha',
#   'Webb Joseph',
#   'Doyle Peter',
#   'Stanbridge Henry',
#   'Gray Wait',
#   'Kerr Walter',
#   'Ham William',
#   'Pulling Richard',
#   'Lewis Phillip',
#   'Bray George',
#   'Seward James',
#   'Marlton John',
#   'Jarvis Edward',
#   'Burbeck William',
#   'Marett Phillip',
#   'Blake Increase',
#   'Cailleteau Edward',
#   'Obear Israel',
#   'Crafts Thomas',
#   'Chipman Seth',
#   'Nicholls Unknown',
#   'Milliken Thomas',
#   'Barrett Samuel',
#   'Jenkins John',
#   'Wingfield William',
#   'Bell William',
#   'Graham James',
#   'Moody Samuel',
#   'Sloper Ambrose',
#   'Potter Edward',
#   'Hoffins John',
#   'Gould William',
#   'Whitten John',
#   'Ash Gilbert',
#   'Webster Thomas',
#   'Hitchborn Nathaniel',
#   'Burbeck Edward',
#   'Phillips John',
#   'Tabor Philip',
#   'Brown Hugh',
#   'Flagg Josiah',
#   'Ferrell Ambrose',
#   'McAlpine William',
#   'Inglish Alexander',
#   'Palfrey William',
#   'Collins Ezra'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Peck Samuel',
#   'Chase Thomas',
#   'Bass Henry',
#   'Crafts Thomas',
#   'Warren Joseph',
#   'Welles Henry',
#   'Barrett Samuel'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Peck Samuel',
#   'Chase Thomas',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Barber Nathaniel',
#   'Eayres Joseph',
#   'Grant Moses',
#   'Proctor Edward',
#   'Story Elisha',
#   'Cooper Samuel',
#   'Collson Adam',
#   'Young Thomas',
#   'Swan James',
#   'Molineux William',
#   'Warren Joseph'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Peck Samuel',
#   'Chase Thomas',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Barber Nathaniel',
#   'Eayres Joseph',
#   'Grant Moses',
#   'Proctor Edward',
#   'Story Elisha',
#   'Cooper Samuel',
#   'Collson Adam',
#   'Young Thomas',
#   'Swan James',
#   'Molineux William',
#   'Mountford Joseph',
#   'Campbell Nicholas',
#   'Eaton Joseph',
#   'Bradlee Nathaniel',
#   'Porter Thomas',
#   'Gammell John',
#   'Burton Benjamin',
#   'Davis Robert',
#   'Bolter Thomas',
#   'Williams Jeremiah',
#   'Slater Peter',
#   'Hewes George',
#   'Sessions Robert',
#   'Purkitt Henry',
#   'Pitts Lendall',
#   'Collier Gershom',
#   'Colesworthy Gilbert',
#   'Morse Anthony',
#   'Wyeth Joshua',
#   'Stearns Phineas',
#   'Wheeler Josiah',
#   'Shed Joseph',
#   'Starr James',
#   'Gore Samuel',
#   'Barnard Samuel',
#   'Hammond Samuel',
#   'Loring Matthew',
#   'Russell William',
#   'May John',
#   'Randall John',
#   'Hunstable Thomas',
#   'Prince John',
#   'Greene Nathaniel',
#   'Hunnewell Jonathan',
#   'Russell John',
#   'Bradlee Thomas',
#   'Lincoln Amos',
#   'Bruce Stephen',
#   'Kinnison David',
#   'Foster Samuel',
#   'Crane John',
#   'Palmer Joseph',
#   'Machin Thomas',
#   'Fenno Samuel',
#   'Roby Joseph',
#   'Dolbear Edward',
#   'Prentiss Henry',
#   'Eckley Unknown',
#   'Hunt Abraham',
#   'Simpson Benjamin',
#   'Clarke Benjamin',
#   'Newell Eliphelet',
#   'Peters John',
#   'Hobbs Samuel',
#   'Hooton John',
#   'Ingersoll Daniel',
#   'Bewer James',
#   'Hicks John',
#   'Parker Jonathan',
#   'Howard Samuel',
#   'Frothingham Nathaniel',
#   'Cochran John',
#   'Pierce William',
#   'Williams Thomas',
#   'Melville Thomas',
#   'Bradlee Josiah',
#   'Willis Nathaniel',
#   'Lee Joseph',
#   'Bradlee David',
#   'Payson Joseph',
#   'Moore Thomas',
#   'Stevens Ebenezer',
#   'Spurr John',
#   'Hunnewell Richard',
#   'MacNeil Archibald',
#   'Spear Thomas',
#   'Hendley William',
#   'Howe Edward',
#   'MacKintosh Capt',
#   'Etheridge William',
#   'Sprague Samuel'],
#  ['Revere Paul',
#   'Urann Thomas',
#   'Peck Samuel',
#   'Chase Thomas',
#   'Bass Henry',
#   'Condy JamesFoster',
#   'Barber Nathaniel',
#   'Eayres Joseph',
#   'Grant Moses',
#   'Proctor Edward',
#   'Barrett Samuel',
#   'Warren Joseph'],
#  ['Revere Paul',
#   'Avery John',
#   'Warren Joseph',
#   'Chase Thomas',
#   'Bass Henry',
#   'Barrett Samuel',
#   'Crafts Thomas',
#   'Welles Henry'],
#  ['Revere Paul',
#   'Avery John',
#   'Warren Joseph',
#   'Chase Thomas',
#   'Bass Henry',
#   'Edes Benjamin',
#   'Barber Nathaniel',
#   'Ruddock Abiel',
#   'Adams Samuel',
#   'Pulling John',
#   'Church Benjamin',
#   'Proctor Edward',
#   'Grant Moses',
#   'Cheever Ezekiel',
#   'Parkman Elias',
#   'Greenleaf Joseph',
#   'Condy JamesFoster',
#   'Winthrop John'],
#  ['Revere Paul',
#   'Avery John',
#   'Warren Joseph',
#   'Chase Thomas',
#   'Bass Henry',
#   'Edes Benjamin',
#   'Welles Henry',
#   'Crafts Thomas'],
#  ['Mackay William',
#   'Warren Joseph',
#   'Barber Nathaniel',
#   'Adams Samuel',
#   'Quincy Josiah',
#   'Sweetser John',
#   'Appleton Nathaniel',
#   'Hill Alexander',
#   'Powell William',
#   'Wendell Oliver',
#   'Bradford John',
#   'Church Benjamin',
#   'Molineux William',
#   'Young Thomas',
#   'Greenleaf William',
#   'Dennie William',
#   'Otis James',
#   'Pierpont Robert',
#   'Davis Caleb',
#   'Greenleaf Joseph',
#   'Boynton Richard'],
#  ['Trott George',
#   'Welles Henry',
#   'Smith John',
#   'Crafts Thomas',
#   'Avery John',
#   'Cleverly Stephen',
#   'Bass Henry',
#   'Chase Thomas',
#   'Edes Benjamin',
#   'Field Joseph']]
