# %% [markdown]
# # KMeans clustering ANY documents

# %% [markdown]
# ## Read in your files if they're all separate

# %%
import pandas as pd
import glob

filenames = glob.glob("fanfiction-twilight/*.txt")

# Maybe use open(filename, encoding='latin-1').read()
# if you're running into trouble
contents = [open(filename, encoding='latin-1').read() for filename in filenames]

df = pd.DataFrame({
    'text': contents,
    'filenames': filenames
})
df.head()
# Out:
#                           filenames  \
# 0  fanfiction-twilight/10016071.txt
# 1  fanfiction-twilight/10016524.txt
# 2  fanfiction-twilight/10019441.txt
# 3  fanfiction-twilight/10021891.txt
# 4  fanfiction-twilight/10029139.txt
#
#                                                 text
# 0  What follows is the original one-shot-no edits...
# 1   A/N: Hey guys this is my new story hope you e...
# 2  I saw him. Him and Bella. But who cares about ...
# 3  Disclaimer: All publicly recognizable characte...
# 4  Thou art a heartless monsterDisclaimer: All re...

# %% [markdown]
# ## Or read in your CSV with the text column if not

# %%
# import pandas as pd
# df = pd.read_csv("")

# %% [markdown]
# ## Vectorize your documents
#
# What are the options when creating a `TfidfVectorizer`?

# %%
TfidfVectorizer?
# Out:
# Object `TfidfVectorizer` not found.

# %% [markdown]
# Let's think about:
#
# * **ngram_rang**: Do we just want single words? Or more? (1,2) is one- and two-word phrases, etc.
# * **max_features**: Can it make things faster? `1` and up
# * **max_df**: Should we ignore words that show up too often? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **min_df**: Should we ignore words that show up too little? `0.0`-`1.0` for percent, OR an integer for absolute document counts
# * **vocabulary**: Only care about certain words
#
# Also... how many documents do we have?

# %%
df.shape
# Out:
# (623, 2)

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob

def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    tokens = blob.words
    words = [token.stem() for token in tokens]
    return words

from sklearn.feature_extraction import stop_words
custom_stopwords = ['just', 'said'] + list(stop_words.ENGLISH_STOP_WORDS)

# Vectorize and save into a new dataframe
vec = TfidfVectorizer(tokenizer=textblob_tokenizer,
                      #stop_words='english',
                      stop_words=custom_stopwords,
                      max_df=0.8, 
                      min_df=0.15,
                      #max_features=250,
                      use_idf=True)

# Fit from the 'text' column of our dataframe
matrix = vec.fit_transform(df['text'])

# Then turn it into a new dataframe
results = pd.DataFrame(matrix.toarray(), columns=vec.get_feature_names())
# Out:
# CPU times: user 44.5 s, sys: 132 ms, total: 44.6 s
# Wall time: 44.8 s

# %%
results.head()
# Out:
#          'd       'll        'm       're       've         1  abl      abov  \
# 0  0.120373  0.174390  0.072623  0.068492  0.000000  0.000000  0.0  0.082942
# 1  0.000000  0.043417  0.084375  0.000000  0.000000  0.025429  0.0  0.000000
# 2  0.000000  0.020692  0.120637  0.021671  0.022188  0.000000  0.0  0.000000
# 3  0.227994  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.000000
# 4  0.039813  0.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.000000
#
#    accept  act   ...     wors      wrap  write     wrong        ye      yeah  \
# 0     0.0  0.0   ...      0.0  0.104500    0.0  0.030917  0.025884  0.000000
# 1     0.0  0.0   ...      0.0  0.000000    0.0  0.041052  0.034368  0.000000
# 2     0.0  0.0   ...      0.0  0.033064    0.0  0.000000  0.024569  0.029347
# 3     0.0  0.0   ...      0.0  0.000000    0.0  0.048800  0.000000  0.000000
# 4     0.0  0.0   ...      0.0  0.000000    0.0  0.000000  0.042804  0.000000
#
#        year      yell     young  younger
# 0  0.042692  0.000000  0.000000      0.0
# 1  0.014172  0.023702  0.000000      0.0
# 2  0.000000  0.000000  0.000000      0.0
# 3  0.235848  0.000000  0.050682      0.0
# 4  0.000000  0.000000  0.000000      0.0
#
# [5 rows x 665 columns]

# %% [markdown]
# > ...Try it without the TextBlob tokenizer

# %% [markdown]
# ## Cluster your documents

# %%
# %%time
from sklearn.cluster import KMeans

# How many clusters?
number_of_clusters=4
km = KMeans(n_clusters=number_of_clusters)

print("Fitting", number_of_clusters, "clusters usinga ", matrix.shape, "matrix")

# Let's fit it!
km.fit(matrix)
km.fit
# Out:
# Fitting 4 clusters usinga  (623, 665) matrix
# CPU times: user 12 s, sys: 57.6 ms, total: 12 s
# Wall time: 12.1 s

# %% [markdown]
# ## See what they look like

# %%
print("Top terms per cluster:")
order_centroids = km.cluster_centers_.argsort()[:, ::-1]
terms = vec.get_feature_names()
for i in range(number_of_clusters):
    top_ten_words = [terms[ind] for ind in order_centroids[i, :10]]
    print("Cluster {}: {}".format(i, ' '.join(top_ten_words)))
# Out:
# Top terms per cluster:
# Cluster 0: 'm hand befor ask say smile head bella 're mom
# Cluster 1: stori vampir love human 'm hope girl onli way life
# Cluster 2: jacob bella charli edward 'm hand love befor away year
# Cluster 3: edward bella alic jasper carlisl emmett 'm hand love ask

# %% [markdown]
# ## Push the category back to the original dataframe

# %%
df['category'] = km.labels_
df
# Out:
#                             filenames  \
# 0    fanfiction-twilight/10016071.txt
# 1    fanfiction-twilight/10016524.txt
# 2    fanfiction-twilight/10019441.txt
# 3    fanfiction-twilight/10021891.txt
# 4    fanfiction-twilight/10029139.txt
# 5    fanfiction-twilight/10029797.txt
# 6    fanfiction-twilight/10030147.txt
# 7    fanfiction-twilight/10042940.txt
# 8    fanfiction-twilight/10046233.txt
# 9    fanfiction-twilight/10047055.txt
# 10   fanfiction-twilight/10050374.txt
# 11   fanfiction-twilight/10050718.txt
# 12   fanfiction-twilight/10058807.txt
# 13   fanfiction-twilight/10060217.txt
# 14   fanfiction-twilight/10060881.txt
# 15   fanfiction-twilight/10061496.txt
# 16   fanfiction-twilight/10064909.txt
# 17   fanfiction-twilight/10078293.txt
# 18   fanfiction-twilight/10079909.txt
# 19   fanfiction-twilight/10082628.txt
# 20   fanfiction-twilight/10086525.txt
# 21   fanfiction-twilight/10086845.txt
# 22   fanfiction-twilight/10087055.txt
# 23   fanfiction-twilight/10088968.txt
# 24   fanfiction-twilight/10090541.txt
# 25   fanfiction-twilight/10103988.txt
# 26   fanfiction-twilight/10109144.txt
# 27   fanfiction-twilight/10109176.txt
# 28   fanfiction-twilight/10109917.txt
# 29   fanfiction-twilight/10120506.txt
# ..                                ...
# 593   fanfiction-twilight/9752376.txt
# 594   fanfiction-twilight/9759104.txt
# 595   fanfiction-twilight/9761533.txt
# 596   fanfiction-twilight/9764168.txt
# 597   fanfiction-twilight/9775624.txt
# 598   fanfiction-twilight/9775934.txt
# 599   fanfiction-twilight/9779069.txt
# 600   fanfiction-twilight/9785972.txt
# 601   fanfiction-twilight/9788953.txt
# 602   fanfiction-twilight/9797824.txt
# 603   fanfiction-twilight/9821325.txt
# 604   fanfiction-twilight/9821671.txt
# 605   fanfiction-twilight/9844398.txt
# 606   fanfiction-twilight/9858083.txt
# 612  1. Prologue(BPOV)I'm frightened.Every night I'...         1
# 613  Please don't kill me for not updating any of m...         0
# 614  I'm trying something new review and tell me wh...         0
# 615  Happy Holidays everyone. Third person povBella...         0
# 616  Rating M: For language, situations and lemons ...         3
# 617  Hello everyone! I hope you enjoy my new story!...         0
# 618  In Fates HandsAN- This is an idea that has bee...         1
# 619  I've never thought I'd die and rise again. I w...         0
# 620  Squeal to My Duty is to My Heart Enjoy! All Ch...         3
# 621  Bella's Pov"Isabella don't eat that it's not g...         0
# 622  A big thanks to SkylerBlue for letting me cont...         1
#
# [623 rows x 3 columns]

# %% [markdown]
# ## Be pleased

# %%
df[df.category == 1]
# Out:
#                             filenames  \
# 2    fanfiction-twilight/10019441.txt
# 6    fanfiction-twilight/10030147.txt
# 9    fanfiction-twilight/10047055.txt
# 25   fanfiction-twilight/10103988.txt
# 26   fanfiction-twilight/10109144.txt
# 27   fanfiction-twilight/10109176.txt
# 29   fanfiction-twilight/10120506.txt
# 30   fanfiction-twilight/10130957.txt
# 39   fanfiction-twilight/10161589.txt
# 46   fanfiction-twilight/10189248.txt
# 57   fanfiction-twilight/10204063.txt
# 60   fanfiction-twilight/10207563.txt
# 61   fanfiction-twilight/10208579.txt
# 62   fanfiction-twilight/10212570.txt
# 63   fanfiction-twilight/10216557.txt
# 64   fanfiction-twilight/10216605.txt
# 66   fanfiction-twilight/10232528.txt
# 67   fanfiction-twilight/10235795.txt
# 68   fanfiction-twilight/10241550.txt
# 72   fanfiction-twilight/10250458.txt
# 76   fanfiction-twilight/10262365.txt
# 78   fanfiction-twilight/10262983.txt
# 79   fanfiction-twilight/10268896.txt
# 80   fanfiction-twilight/10269161.txt
# 81   fanfiction-twilight/10273916.txt
# 87   fanfiction-twilight/10294367.txt
# 91   fanfiction-twilight/10301389.txt
# 92   fanfiction-twilight/10302586.txt
# 96   fanfiction-twilight/10323040.txt
# 97   fanfiction-twilight/10323045.txt
# ..                                ...
# 521   fanfiction-twilight/8962912.txt
# 524   fanfiction-twilight/8996197.txt
# 526   fanfiction-twilight/9038159.txt
# 535   fanfiction-twilight/9176270.txt
# 537   fanfiction-twilight/9235498.txt
# 538   fanfiction-twilight/9245557.txt
# 546   fanfiction-twilight/9350379.txt
# 552   fanfiction-twilight/9382021.txt
# 557   fanfiction-twilight/9457516.txt
# 559   fanfiction-twilight/9463656.txt
# 562   fanfiction-twilight/9507423.txt
# 565   fanfiction-twilight/9544658.txt
# 567   fanfiction-twilight/9564350.txt
# 570   fanfiction-twilight/9584935.txt
# 571   fanfiction-twilight/9599527.txt
# 573   fanfiction-twilight/9613741.txt
# 575   fanfiction-twilight/9632720.txt
# 576   fanfiction-twilight/9643272.txt
# 577   fanfiction-twilight/9643999.txt
# 579   fanfiction-twilight/9670479.txt
# 582   fanfiction-twilight/9691564.txt
# 593   fanfiction-twilight/9752376.txt
# 595   fanfiction-twilight/9761533.txt
# 600   fanfiction-twilight/9785972.txt
# 609   fanfiction-twilight/9881221.txt
# 611   fanfiction-twilight/9919438.txt
# 616   fanfiction-twilight/9979704.txt
# 617   fanfiction-twilight/9984045.txt
# 620   fanfiction-twilight/9990417.txt
# 621   fanfiction-twilight/9990870.txt
#
